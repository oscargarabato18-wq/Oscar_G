# %% [markdown]
# <a href="https://colab.research.google.com/github/oscargarabato18-wq/Oscar_G/blob/main/ejerclass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #presupuesto - mostrar inofrmacion usuario

# %%
proyecto = input("de que se trata tu proyecto ? ")
horaExrimada = input(" escriba las horas extimada del proyecto:")
valor_hora = input("escriba el valor de la hora: ")
plazo = input("escriba el plazo del proyecto: ")
#
# Out:
# de que se trata tu proyecto ? cerveza
#  escriba las horas extimada del proyecto:6 horas
# escriba el valor de la hora: 2000
# escriba el plazo del proyecto: 6 mese

# %%
print(proyecto)
print(horaExrimada)
print(valor_hora)
print(plazo)
#
# Out:
# cerveza
# 6 horas
# 2000
# 6 mese

# %% [markdown]
# #calculo con python

# %%
valor_total = int(horaExrimada.split()[0]) * int(valor_hora)
print(valor_total)
# Out:
# 12000

# %% [markdown]
# #genera archivo pdf del presupuesto

# %%
# !pip install fpdf #instalamos lalibreria
from fpdf import FPDF #importamos la libreria
pdf = FPDF() #variable
pdf.add_page()
pdf.set_font("Arial")
pdf.set_font_size(14)
pdf.image("plantilla.jpeg", 8,1)
pdf.text(115, 145, proyecto)
pdf.text(115, 160, horaExrimada)
pdf.text(115, 175, valor_hora)
pdf.text(115, 190, plazo)
pdf.text(115, 205, str(valor_total))



pdf.output("presupuesto.pdf")
# Out:
# ...
# ''

# %%
from google.colab import drive
drive.mount('/content/drive')
